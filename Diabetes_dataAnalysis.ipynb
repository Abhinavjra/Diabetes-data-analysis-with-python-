# %%
# import library for manipulatioon and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes1_df = pd.read_csv('/content/diabetes.csv')  #import datasets

# %%
diabete_df = diabetes1_df.copy() #make copy of dataset for safety purpose

# %% [markdown]
# # **Our Data dictionary:**
# Below is the attribute information:
# Pregnancies: Number of times pregnant
#
# Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
# Blood pressure: Diastolic blood pressure (mm Hg)
#
# SkinThickness: Triceps skinfold thickness (mm)
#
# Insulin: 2-Hour serum insulin (mu U/ml) test
#
# BMI: Body mass index (weight in kg/(height in m)^2)
#
# DiabetesPedigreeFunction: A function that scores the likelihood of diabetes based on family history
#
# Age: Age in years
#
# Outcome: Class variable (0: the person is not diabetic or 1: the person is diabetic)

# %%
#show top 5 rows of datasets
diabete_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#show some impormation regarding dataset like null value ,datatupe all row
diabete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabete_df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
diabete_df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
diabete_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Good! There are no null values in our dataset. Let us move on to visualizing the dataset to gather more insights about the data.

# %%
diab_col = list(diabete_df.columns)

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
plt.figure(figsize = (20,60))
for i,col in enumerate(diab_col):
  plt.subplot(9,2,2*i+1)
  sns.histplot(data = diabete_df,x = col,kde = True,color = 'green')

  plt.subplot(9,2,2*i+2)
  sns.boxplot(data = diabete_df,x = col)

# %%
print('median of pregnancy',diabete_df['Pregnancies'].median())
print('Maximum of pregnancy',diabete_df['Pregnancies'].max())
# Out:
# median of pregnancy 3.0
# Maximum of pregnancy 17

# %%
print("Median of Glucose: ", diabete_df["Glucose"].median())
print("Maximum of Glucose: ", diabete_df["Glucose"].max())
print("Mean of Glucose: ", diabete_df["Glucose"].mean())
# Out:
# Median of Glucose:  117.0
# Maximum of Glucose:  199
# Mean of Glucose:  120.89453125

# %% [markdown]
# As you can see above
#
# Average glucose level is 120
#
# maximum glucose value is 199
#
# and mostly pepole contains 117

# %%
diabete_df.groupby(['Pregnancies']).size()
# Out:
# Pregnancies
# 0     111
# 1     135
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 12      9
# 13     10
# 14      2
# 15      1
# 17      1
# dtype: int64

# %% [markdown]
# ### **From the above analysis we observe that:**
#
# Most patients had 0, 1 or 2 pregnancies.
#
# Median value of Pregnancies is 3.
#
# Also, patients had upto 17 pregnancies!

# %%
print("Median of Blood Pressure: ", diabete_df["BloodPressure"].median())
print("Maximum of Blood Pressure: ", diabete_df["BloodPressure"].max())
print("Mean of Blood Pressure: ", diabete_df["BloodPressure"].mean())
# Out:
# Median of Blood Pressure:  72.0
# Maximum of Blood Pressure:  122
# Mean of Blood Pressure:  69.10546875

# %%
print("contains 0 value rows",diabete_df[diabete_df["BloodPressure"] == 0].shape[0])
# Out:
# contains 0 value rows 35

# %% [markdown]
# ### We observe that:​
#
# Median (72.0) and mean (69.1) of BloodPressure lie very close to each other i.e. the distribution is more or less symmetric and uniform.
#
# As seen from the box plot and violin plot, some outliers lie on 0-value, which I talked about earlier.
#
# There are 35 rows with BloodPressure value as 0. This is not logical.

# %%
print("Median of  Bmi: ", diabete_df["BMI"].median())
print("Maximum of Bmi: ", diabete_df["BMI"].max())
print("Mean of Bmi: ", diabete_df["BMI"].mean())
print("contains 0 value rows",diabete_df[diabete_df["BMI"] == 0].shape[0])
# Out:
# Median of  Bmi:  32.0
# Maximum of Bmi:  67.1
# Mean of Bmi:  31.992578124999998
# contains 0 value rows 11

# %% [markdown]
# We observe that:
#
# Median (32.0) and Mean (31.9) of BMI are very close to each other. Thus, the distribution is more or less symmetric and uniform
#
# Maximum BMI is 67.1
#
# There are 11 rows with BMI value as 0

# %%
diab_col = list(diabete_df.columns)

# %%
diab_col
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
sns.countplot(data = diabete_df, x = 'Outcome')

plt.subplot(1,2,2)
diabete_df['Outcome'].value_counts().plot.pie(autopct = "%1.1f%%",labels = ['No','yes'],shadow = True)
# Out:
# <Axes: ylabel='Outcome'>

# %% [markdown]
# ### **We observe from the above plot that:**
#
# 65.1% patients in the dataset do NOT have diabetes.
#
# 34.9% patients in the dataset has diabetes.

# %% [markdown]
# # **BIVARIATE ANALYSIS**

# %%
corr_df  = diabete_df.corr()

# %%
plt.figure(figsize=(20,35))
for i,col in enumerate(diab_col):
  plt.subplot(9,2,i+1)
  sns.histplot(data = diabete_df,x = col, hue = 'Outcome',kde = True,shrink = 0.8)

# %% [markdown]
# From the above plot, we see a positive linear correlation.
#
# As the value of Glucose increases, the count of patients having diabetes increases i.e. value of Outcome as 1, increases.
#
# Also, after the Glucose value of 125, there is a steady increase in the number of patients having Outcome of 1.
#
# Note, when Glucose value is 0, it means the measurement is missing. We need to fill that values with the mean or median and then it will make sense.
#
# So, there is a significant amount of positive linear correlation.
#
#
# Outcome and BloodPressure do NOT have a positive or negative linear correlation. The value of Outcome do not increase linearly as value of BloodPressure increases.
#
# However, for BloodPressure values greater than 82, count of patients with Outcome as 1, is more.

# %% [markdown]
# For Age greater than 35 years, the chances of patients having diabetes increases as evident from the plot i.e. The number of patients having diabetes is more than the number of people NOT having diabetes. But, it does not hold true for ages like 60+, somehow.
#
# There is some positive linear correlation though.

# %%
sns.scatterplot(data = diabete_df,x='Glucose',y = 'Age')
# Out:
# <Axes: xlabel='Glucose', ylabel='Age'>

# %%
diabete_copy_df = diabete_df.copy()

# %%
diabete_copy_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabete_copy_df[diabete_copy_df['Glucose']==0].shape[0]


diabete_copy_df['Glucose'] = diabete_copy_df['Glucose'].replace(0,diabete_copy_df['Glucose'].median())

# %%
diabete_copy_df[diabete_copy_df['Glucose']==0].shape[0]
# Out:
# 0

# %%
for col in diabete_copy_df.columns:
  diabete_copy_df[col] = diabete_copy_df[col].replace(0,diabete_copy_df[col].median())

# %%
corr_data_new = diabete_copy_df.corr()

# %%
corr_data_new
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.149326       0.247530       0.060706
# Glucose                      0.149326  1.000000       0.218937       0.172143
# BloodPressure                0.247530  0.218937       1.000000       0.147809
# SkinThickness                0.060706  0.172143       0.147809       1.000000
# Insulin                     -0.059580  0.357573      -0.028721       0.238188
# BMI                          0.080540  0.231400       0.281132       0.546951
# DiabetesPedigreeFunction    -0.016151  0.137327      -0.002378       0.142977
# Age                          0.538169  0.266909       0.324915       0.054514
# Outcome                      0.245466  0.492782       0.165723       0.189065
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.059580  0.080540                 -0.016151
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data = corr_data_new,cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# We observe that:
#
# Glucose has the maximum positive linear correlation with Outcome, which is logical.
#
# BloodPressure has the lowest positive linear correlation with Outcome.
#
# No feature has a negative linear correlation with Outcome.

# %%
diabetes_data =  diabete_copy_df.drop(labels='Outcome',axis = 1)

# %%
#importing library for machine learning module
from sklearn.preprocessing import StandardScaler
from mlxtend.plotting import plot_decision_regions
import missingno as msno
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
scaler = StandardScaler()

# %%
diabetes_data_standardize = pd.DataFrame(scaler.fit_transform(diabetes_data),columns = diabetes_data.columns)

# %%
x = diabetes_data_standardize.copy()

# %%
diabetes_data_standardize.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.570070  0.866045      -0.031990       0.831114 -0.608201  0.167240
# 1    -1.085807 -1.205066      -0.528319       0.180566 -0.608201 -0.851551
# 2     1.232421  2.016662      -0.693761      -0.469981 -0.608201 -1.331838
# 3    -1.085807 -1.073567      -0.528319      -0.469981 -0.006185 -0.633239
# 4    -0.423456  0.504422      -2.679076       0.831114  0.695378  1.549885
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %%
y = diabete_copy_df.Outcome

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # **Split The Data Into Train And TEST**

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=1/3,random_state = 42,stratify = y)

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# ## **K NEAREST NEIGBOR KNN**

# %%
test_scores = []
train_scores = []
for i in range(1,15):

  knn = KNeighborsClassifier(i)
  knn.fit(x_train,y_train)

  train_scores.append(knn.score(x_train,y_train))
  test_scores.append(knn.score(x_test,y_test))

# %%
train_scores
# Out:
# [1.0,
#  0.833984375,
#  0.853515625,
#  0.814453125,
#  0.83984375,
#  0.802734375,
#  0.8203125,
#  0.787109375,
#  0.802734375,
#  0.794921875,
#  0.810546875,
#  0.806640625,
#  0.814453125,
#  0.806640625]

# %%
test_scores
# Out:
# [0.71484375,
#  0.69921875,
#  0.7109375,
#  0.69921875,
#  0.73046875,
#  0.734375,
#  0.71484375,
#  0.7109375,
#  0.74609375,
#  0.734375,
#  0.75,
#  0.75,
#  0.74609375,
#  0.73828125]

# %%
max_train_score = max(train_scores)
train_score_ind = [i for i,v in enumerate(train_scores)if v ==max(train_scores)]
print('max_train_score {} % and k {}'.format(max_train_score*100,list(map(lambda x : x+1,train_score_ind))))
# Out:
# max_train_score 100.0 % and k [1]

# %%
max_test_score = max(test_scores)
test_score_ind = [i for i,v in enumerate(test_scores)if v ==max(test_scores)]
print('max_tests_score {} % and k {}'.format(max_test_score*100,list(map(lambda x : x+1,test_score_ind))))
# Out:
# max_tests_score 75.0 % and k [11, 12]

# %%
plt.figure(figsize = (12,5))
p = sns.lineplot(range(1,15),train_scores,marker = '*',label = 'Train Score')
p = sns.lineplot(range(1,15),test_scores,marker = 'o',label = 'Test Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-266e66a762cc> in <cell line: 2>()
#       1 plt.figure(figsize = (12,5))
# ----> 2 p = sns.lineplot(range(1,15),train_scores,marker = '*',label = 'Train Score')
#       3 p = sns.lineplot(range(1,15),test_scores,marker = 'o',label = 'Test Score')
#       4 plt.show()
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given
